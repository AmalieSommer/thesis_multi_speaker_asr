# %%
import pstats

p = pstats.Stats("profile.prof")
p.sort_stats("cumulative")
p.print_stats(30)
# Out:
# Thu Jun  4 11:04:33 2026    profile.prof
#
#          10919451 function calls (10761829 primitive calls) in 870.299 seconds
#
#    Ordered by: cumulative time
#    List reduced from 16638 to 30 due to restriction <30>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    4434/1    0.126    0.000  870.439  870.439 {built-in method builtins.exec}
#         1    0.000    0.000  870.439  870.439 src/multi_speaker_asr/main.py:1(<module>)
#         1    0.000    0.000  867.082  867.082 src/multi_speaker_asr/main.py:59(exp1)
#         1    0.097    0.097  867.082  867.082 /root/master_thesis/thesis_multi_speaker_asr/src/multi_speaker_asr/evaluate.py:56(inference_asr)
#      2929    0.040    0.000  796.312    0.272 /root/master_thesis/thesis_multi_speaker_asr/.venv/lib/python3.11/site-packages/faster_whisper/transcribe.py:1844(restore_speech_timestamps)
# ...

# %%
p.print_callers(30)
# Out:
#    Ordered by: cumulative time
#    List reduced from 16638 to 30 due to restriction <30>
#
# Function                                                                                                                                       was called by...
#                                                                                                                                                    ncalls  tottime  cumtime
# {built-in method builtins.exec}                                                                                                                <-    1490    0.094    0.095  /root/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/dataclasses.py:413(_create_fn)
# ...

# %%
p.print_callees(30)
# Out:
#    Ordered by: cumulative time
#    List reduced from 16638 to 30 due to restriction <30>
#
# Function                                                                                                                                       called...
#                                                                                                                                                    ncalls  tottime  cumtime
# {built-in method builtins.exec}                                                                                                                ->       1    0.000    0.000  /root/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/__future__.py:1(<module>)
#                                                                                                                                                         1    0.000    0.000  /root/.local/share/uv/python/cpython-3.11.14-linux-x86_64-gnu/lib/python3.11/_compat_pickle.py:1(<module>)
# ...

# %%
import pstats

# %%
p = pstats.Stats("profile2.prof")
p.sort_stats("cumulative")
p.print_stats(20)
# Out:
# Thu Jun  4 17:43:40 2026    profile2.prof
#
#          8888691 function calls (8742577 primitive calls) in 760.017 seconds
#
#    Ordered by: cumulative time
#    List reduced from 16630 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    4434/1    0.130    0.000  760.139  760.139 {built-in method builtins.exec}
#         1    0.000    0.000  760.139  760.139 src/multi_speaker_asr/main.py:1(<module>)
#         1    0.020    0.020  756.853  756.853 src/multi_speaker_asr/main.py:59(exp1)
#         1    0.184    0.184  756.833  756.833 /root/master_thesis/thesis_multi_speaker_asr/src/multi_speaker_asr/evaluate.py:53(inference_asr)
#      1003    0.010    0.000  636.229    0.634 /root/master_thesis/thesis_multi_speaker_asr/.venv/lib/python3.11/site-packages/faster_whisper/transcribe.py:1844(restore_speech_timestamps)
# ...
